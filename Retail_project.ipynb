# %%
from unittest.mock import inplace

import pandas as pd
import matplotlib as plt
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv("data/Retail_Sales.csv")

# %% [markdown]
# # **CLEANING**

# %%
df
# Out:
#       transactions_id   sale_date sale_time  customer_id  gender   age  \
# 0                 180  2022-11-05  10:47:00          117    Male  41.0
# 1                 522  2022-07-09  11:00:00           52    Male  46.0
# 2                 559  2022-12-12  10:48:00            5  Female  40.0
# 3                1180  2022-01-06  08:53:00           85    Male  41.0
# 4                1522  2022-11-14  08:35:00           48    Male  46.0
# ...               ...         ...       ...          ...     ...   ...
# 1995             1857  2022-11-09  12:15:00          109    Male  60.0
# 1996              211  2022-09-12  14:02:00           54    Male  42.0
# 1997              650  2023-10-08  12:41:00           98    Male  55.0
# 1998             1211  2023-11-22  14:59:00           82    Male  42.0
# 1999             1650  2022-09-23  16:24:00           89    Male  55.0
#
#          category  quantiy  price_per_unit   cogs  total_sale
# ...

# %%
df.dropna()
# Out:
#       transactions_id   sale_date sale_time  customer_id  gender   age  \
# 0                 180  2022-11-05  10:47:00          117    Male  41.0
# 1                 522  2022-07-09  11:00:00           52    Male  46.0
# 2                 559  2022-12-12  10:48:00            5  Female  40.0
# 3                1180  2022-01-06  08:53:00           85    Male  41.0
# 4                1522  2022-11-14  08:35:00           48    Male  46.0
# ...               ...         ...       ...          ...     ...   ...
# 1995             1857  2022-11-09  12:15:00          109    Male  60.0
# 1996              211  2022-09-12  14:02:00           54    Male  42.0
# 1997              650  2023-10-08  12:41:00           98    Male  55.0
# 1998             1211  2023-11-22  14:59:00           82    Male  42.0
# 1999             1650  2022-09-23  16:24:00           89    Male  55.0
#
#          category  quantiy  price_per_unit   cogs  total_sale
# ...

# %%
df.isnull().sum()
# Out:
# transactions_id     0
# sale_date           0
# sale_time           0
# customer_id         0
# gender              0
# age                10
# category            0
# quantiy             3
# price_per_unit      3
# cogs                3
# total_sale          3
# Revenue             3
# Day_Name            0
# dtype: int64

# %%
df.fillna(0)
# Out:
#       transactions_id  sale_date sale_time  customer_id  gender   age  \
# 0                 180 2022-11-05  10:47:00          117    Male  41.0
# 1                 522 2022-07-09  11:00:00           52    Male  46.0
# 2                 559 2022-12-12  10:48:00            5  Female  40.0
# 3                1180 2022-01-06  08:53:00           85    Male  41.0
# 4                1522 2022-11-14  08:35:00           48    Male  46.0
# ...               ...        ...       ...          ...     ...   ...
# 1995             1857 2022-11-09  12:15:00          109    Male  60.0
# 1996              211 2022-09-12  14:02:00           54    Male  42.0
# 1997              650 2023-10-08  12:41:00           98    Male  55.0
# 1998             1211 2023-11-22  14:59:00           82    Male  42.0
# 1999             1650 2022-09-23  16:24:00           89    Male  55.0
#
#          category  quantiy  price_per_unit   cogs  total_sale  Revenue  \
# ...

# %%
df.isnull().sum()
# Out:
# transactions_id     0
# sale_date           0
# sale_time           0
# customer_id         0
# gender              0
# age                10
# category            0
# quantiy             3
# price_per_unit      3
# cogs                3
# total_sale          3
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1995    False
# 1996    False
# 1997    False
# 1998    False
# 1999    False
# Length: 2000, dtype: bool

# %% [markdown]
# # **Transform The Dataset**

# %%
df["sale_date"] = pd.to_datetime(df["sale_date"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   transactions_id  2000 non-null   int64
#  1   sale_date        2000 non-null   datetime64[ns]
#  2   sale_time        2000 non-null   object
#  3   customer_id      2000 non-null   int64
#  4   gender           2000 non-null   object
#  5   age              1990 non-null   float64
#  6   category         2000 non-null   object
#  7   quantiy          1997 non-null   float64
#  8   price_per_unit   1997 non-null   float64
#  9   cogs             1997 non-null   float64
#  10  total_sale       1997 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(2), object(3)
# memory usage: 172.0+ KB

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#       transactions_id  sale_date sale_time  customer_id  gender   age  \
# 0                 180 2022-11-05  10:47:00          117    Male  41.0
# 1                 522 2022-07-09  11:00:00           52    Male  46.0
# 2                 559 2022-12-12  10:48:00            5  Female  40.0
# 3                1180 2022-01-06  08:53:00           85    Male  41.0
# 4                1522 2022-11-14  08:35:00           48    Male  46.0
# ...               ...        ...       ...          ...     ...   ...
# 1995             1857 2022-11-09  12:15:00          109    Male  60.0
# 1996              211 2022-09-12  14:02:00           54    Male  42.0
# 1997              650 2023-10-08  12:41:00           98    Male  55.0
# 1998             1211 2023-11-22  14:59:00           82    Male  42.0
# 1999             1650 2022-09-23  16:24:00           89    Male  55.0
#
#          category  quantiy  price_per_unit   cogs  total_sale
# 0        Clothing      3.0           300.0  129.0       900.0
# ...

# %%
df["sale_date"] = pd.to_datetime(df["sale_date"])

# %%
df
# Out:
#       transactions_id  sale_date sale_time  customer_id  gender   age  \
# 0                 180 2022-11-05  10:47:00          117    Male  41.0
# 1                 522 2022-07-09  11:00:00           52    Male  46.0
# 2                 559 2022-12-12  10:48:00            5  Female  40.0
# 3                1180 2022-01-06  08:53:00           85    Male  41.0
# 4                1522 2022-11-14  08:35:00           48    Male  46.0
# ...               ...        ...       ...          ...     ...   ...
# 1995             1857 2022-11-09  12:15:00          109    Male  60.0
# 1996              211 2022-09-12  14:02:00           54    Male  42.0
# 1997              650 2023-10-08  12:41:00           98    Male  55.0
# 1998             1211 2023-11-22  14:59:00           82    Male  42.0
# 1999             1650 2022-09-23  16:24:00           89    Male  55.0
#
#          category  quantiy  price_per_unit   cogs  total_sale  Revenue  \
# ...

# %%
df.isnull()
# Out:
#       transactions_id  sale_date  sale_time  customer_id  gender    age  \
# 0               False      False      False        False   False  False
# 1               False      False      False        False   False  False
# 2               False      False      False        False   False  False
# 3               False      False      False        False   False  False
# 4               False      False      False        False   False  False
# ...               ...        ...        ...          ...     ...    ...
# 1995            False      False      False        False   False  False
# 1996            False      False      False        False   False  False
# 1997            False      False      False        False   False  False
# 1998            False      False      False        False   False  False
# 1999            False      False      False        False   False  False
#
#       category  quantiy  price_per_unit   cogs  total_sale
# ...

# %%
df.isnull().sum()
# Out:
# transactions_id     0
# sale_date           0
# sale_time           0
# customer_id         0
# gender              0
# age                10
# category            0
# quantiy             3
# price_per_unit      3
# cogs                3
# total_sale          3
# dtype: int64

# %%
df.dropna()
# Out:
#       transactions_id  sale_date sale_time  customer_id  gender   age  \
# 0                 180 2022-11-05  10:47:00          117    Male  41.0
# 1                 522 2022-07-09  11:00:00           52    Male  46.0
# 2                 559 2022-12-12  10:48:00            5  Female  40.0
# 3                1180 2022-01-06  08:53:00           85    Male  41.0
# 4                1522 2022-11-14  08:35:00           48    Male  46.0
# ...               ...        ...       ...          ...     ...   ...
# 1995             1857 2022-11-09  12:15:00          109    Male  60.0
# 1996              211 2022-09-12  14:02:00           54    Male  42.0
# 1997              650 2023-10-08  12:41:00           98    Male  55.0
# 1998             1211 2023-11-22  14:59:00           82    Male  42.0
# 1999             1650 2022-09-23  16:24:00           89    Male  55.0
#
#          category  quantiy  price_per_unit   cogs  total_sale
# 0        Clothing      3.0           300.0  129.0       900.0
# ...

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#       transactions_id  sale_date sale_time  customer_id  gender   age  \
# 0                 180 2022-11-05  10:47:00          117    Male  41.0
# 1                 522 2022-07-09  11:00:00           52    Male  46.0
# 2                 559 2022-12-12  10:48:00            5  Female  40.0
# 3                1180 2022-01-06  08:53:00           85    Male  41.0
# 4                1522 2022-11-14  08:35:00           48    Male  46.0
# ...               ...        ...       ...          ...     ...   ...
# 1995             1857 2022-11-09  12:15:00          109    Male  60.0
# 1996              211 2022-09-12  14:02:00           54    Male  42.0
# 1997              650 2023-10-08  12:41:00           98    Male  55.0
# 1998             1211 2023-11-22  14:59:00           82    Male  42.0
# 1999             1650 2022-09-23  16:24:00           89    Male  55.0
#
#          category  quantiy  price_per_unit   cogs  total_sale
# 0        Clothing      3.0           300.0  129.0       900.0
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1995    False
# 1996    False
# 1997    False
# 1998    False
# 1999    False
# Length: 1987, dtype: bool

# %%
df.columns
# Out:
# Index(['transactions_id', 'sale_date', 'sale_time', 'customer_id', 'gender',
#        'age', 'category', 'quantiy', 'price_per_unit', 'cogs', 'total_sale'],
#       dtype='object')

# %%
df[df['quantiy']<0]
df[df["price_per_unit"]<0]
# Out:
# Empty DataFrame
# Columns: [transactions_id, sale_date, sale_time, customer_id, gender, age, category, quantiy, price_per_unit, cogs, total_sale]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1987 entries, 0 to 1999
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   transactions_id  1987 non-null   int64
#  1   sale_date        1987 non-null   datetime64[ns]
#  2   sale_time        1987 non-null   object
#  3   customer_id      1987 non-null   int64
#  4   gender           1987 non-null   object
#  5   age              1987 non-null   float64
#  6   category         1987 non-null   object
#  7   quantiy          1987 non-null   float64
#  8   price_per_unit   1987 non-null   float64
#  9   cogs             1987 non-null   float64
#  10  total_sale       1987 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(2), object(3)
# memory usage: 186.3+ KB

# %% [markdown]
# # ******Featured Engineering******

# %%
df["Revenue"] = df["quantiy"]*df["price_per_unit"]

# %%
df.columns
# Out:
# Index(['transactions_id', 'sale_date', 'sale_time', 'customer_id', 'gender',
#        'age', 'category', 'quantiy', 'price_per_unit', 'cogs', 'total_sale',
#        'Revenue'],
#       dtype='object')

# %%
df
# Out:
#       transactions_id  sale_date sale_time  customer_id  gender   age  \
# 0                 180 2022-11-05  10:47:00          117    Male  41.0
# 1                 522 2022-07-09  11:00:00           52    Male  46.0
# 2                 559 2022-12-12  10:48:00            5  Female  40.0
# 3                1180 2022-01-06  08:53:00           85    Male  41.0
# 4                1522 2022-11-14  08:35:00           48    Male  46.0
# ...               ...        ...       ...          ...     ...   ...
# 1995             1857 2022-11-09  12:15:00          109    Male  60.0
# 1996              211 2022-09-12  14:02:00           54    Male  42.0
# 1997              650 2023-10-08  12:41:00           98    Male  55.0
# 1998             1211 2023-11-22  14:59:00           82    Male  42.0
# 1999             1650 2022-09-23  16:24:00           89    Male  55.0
#
#          category  quantiy  price_per_unit   cogs  total_sale  Revenue
# ...

# %%
df['Year'] = df['sale_date'].dt.year

# %%
df
# Out:
#       transactions_id  sale_date sale_time  customer_id  gender   age  \
# 0                 180 2022-11-05  10:47:00          117    Male  41.0
# 1                 522 2022-07-09  11:00:00           52    Male  46.0
# 2                 559 2022-12-12  10:48:00            5  Female  40.0
# 3                1180 2022-01-06  08:53:00           85    Male  41.0
# 4                1522 2022-11-14  08:35:00           48    Male  46.0
# ...               ...        ...       ...          ...     ...   ...
# 1995             1857 2022-11-09  12:15:00          109    Male  60.0
# 1996              211 2022-09-12  14:02:00           54    Male  42.0
# 1997              650 2023-10-08  12:41:00           98    Male  55.0
# 1998             1211 2023-11-22  14:59:00           82    Male  42.0
# 1999             1650 2022-09-23  16:24:00           89    Male  55.0
#
#          category  quantiy  price_per_unit   cogs  total_sale  Revenue  Year
# ...

# %%
df.columns
# Out:
# Index(['transactions_id', 'sale_date', 'sale_time', 'customer_id', 'gender',
#        'age', 'category', 'quantiy', 'price_per_unit', 'cogs', 'total_sale',
#        'Revenue', 'Year'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1987 entries, 0 to 1999
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   transactions_id  1987 non-null   int64
#  1   sale_date        1987 non-null   datetime64[ns]
#  2   sale_time        1987 non-null   object
#  3   customer_id      1987 non-null   int64
#  4   gender           1987 non-null   object
#  5   age              1987 non-null   float64
#  6   category         1987 non-null   object
#  7   quantiy          1987 non-null   float64
#  8   price_per_unit   1987 non-null   float64
#  9   cogs             1987 non-null   float64
#  10  total_sale       1987 non-null   float64
#  11  Revenue          1987 non-null   float64
#  12  Year             1987 non-null   int32
# dtypes: datetime64[ns](1), float64(6), int32(1), int64(2), object(3)
# memory usage: 209.6+ KB

# %%
df["Month"] = df["sale_date"].dt.month

# %%
df
# Out:
#       transactions_id  sale_date sale_time  customer_id  gender   age  \
# 0                 180 2022-11-05  10:47:00          117    Male  41.0
# 1                 522 2022-07-09  11:00:00           52    Male  46.0
# 2                 559 2022-12-12  10:48:00            5  Female  40.0
# 3                1180 2022-01-06  08:53:00           85    Male  41.0
# 4                1522 2022-11-14  08:35:00           48    Male  46.0
# ...               ...        ...       ...          ...     ...   ...
# 1995             1857 2022-11-09  12:15:00          109    Male  60.0
# 1996              211 2022-09-12  14:02:00           54    Male  42.0
# 1997              650 2023-10-08  12:41:00           98    Male  55.0
# 1998             1211 2023-11-22  14:59:00           82    Male  42.0
# 1999             1650 2022-09-23  16:24:00           89    Male  55.0
#
#          category  quantiy  price_per_unit   cogs  total_sale  Revenue  Year  \
# ...

# %%
df["Day"] = df["sale_date"].dt.day

# %%
df
# Out:
#       transactions_id  sale_date sale_time  customer_id  gender   age  \
# 0                 180 2022-11-05  10:47:00          117    Male  41.0
# 1                 522 2022-07-09  11:00:00           52    Male  46.0
# 2                 559 2022-12-12  10:48:00            5  Female  40.0
# 3                1180 2022-01-06  08:53:00           85    Male  41.0
# 4                1522 2022-11-14  08:35:00           48    Male  46.0
# ...               ...        ...       ...          ...     ...   ...
# 1995             1857 2022-11-09  12:15:00          109    Male  60.0
# 1996              211 2022-09-12  14:02:00           54    Male  42.0
# 1997              650 2023-10-08  12:41:00           98    Male  55.0
# 1998             1211 2023-11-22  14:59:00           82    Male  42.0
# 1999             1650 2022-09-23  16:24:00           89    Male  55.0
#
#          category  quantiy  price_per_unit   cogs  total_sale  Revenue  Year  \
# ...

# %%
df['Day_Name'] = df['sale_date'].dt.day_name()

# %%
df
# Out:
#       transactions_id  sale_date sale_time  customer_id  gender   age  \
# 0                 180 2022-11-05  10:47:00          117    Male  41.0
# 1                 522 2022-07-09  11:00:00           52    Male  46.0
# 2                 559 2022-12-12  10:48:00            5  Female  40.0
# 3                1180 2022-01-06  08:53:00           85    Male  41.0
# 4                1522 2022-11-14  08:35:00           48    Male  46.0
# ...               ...        ...       ...          ...     ...   ...
# 1995             1857 2022-11-09  12:15:00          109    Male  60.0
# 1996              211 2022-09-12  14:02:00           54    Male  42.0
# 1997              650 2023-10-08  12:41:00           98    Male  55.0
# 1998             1211 2023-11-22  14:59:00           82    Male  42.0
# 1999             1650 2022-09-23  16:24:00           89    Male  55.0
#
#          category  quantiy  price_per_unit   cogs  total_sale  Revenue  \
# ...

# %%
total_revenue  = df["Revenue"].sum()

# %%
df
# Out:
#       transactions_id  sale_date sale_time  customer_id  gender   age  \
# 0                 180 2022-11-05  10:47:00          117    Male  41.0
# 1                 522 2022-07-09  11:00:00           52    Male  46.0
# 2                 559 2022-12-12  10:48:00            5  Female  40.0
# 3                1180 2022-01-06  08:53:00           85    Male  41.0
# 4                1522 2022-11-14  08:35:00           48    Male  46.0
# ...               ...        ...       ...          ...     ...   ...
# 1995             1857 2022-11-09  12:15:00          109    Male  60.0
# 1996              211 2022-09-12  14:02:00           54    Male  42.0
# 1997              650 2023-10-08  12:41:00           98    Male  55.0
# 1998             1211 2023-11-22  14:59:00           82    Male  42.0
# 1999             1650 2022-09-23  16:24:00           89    Male  55.0
#
#          category  quantiy  price_per_unit   cogs  total_sale  Revenue  Year  \
# ...

# %% [markdown]
# # **Customer Analysis**

# %%
total_orders = df['transactions_id'].nunique()

# %%
df
# Out:
#       transactions_id  sale_date sale_time  customer_id  gender   age  \
# 0                 180 2022-11-05  10:47:00          117    Male  41.0
# 1                 522 2022-07-09  11:00:00           52    Male  46.0
# 2                 559 2022-12-12  10:48:00            5  Female  40.0
# 3                1180 2022-01-06  08:53:00           85    Male  41.0
# 4                1522 2022-11-14  08:35:00           48    Male  46.0
# ...               ...        ...       ...          ...     ...   ...
# 1995             1857 2022-11-09  12:15:00          109    Male  60.0
# 1996              211 2022-09-12  14:02:00           54    Male  42.0
# 1997              650 2023-10-08  12:41:00           98    Male  55.0
# 1998             1211 2023-11-22  14:59:00           82    Male  42.0
# 1999             1650 2022-09-23  16:24:00           89    Male  55.0
#
#          category  quantiy  price_per_unit   cogs  total_sale  Revenue  Year  \
# ...

# %%
total_customer = df["customer_id"].nunique()

# %%
total_products = df["transactions_id"].nunique()

# %%
total_quantity = df["quantiy"].sum()

# %%
average_order_value = total_revenue / total_orders

# %%
df
# Out:
#       transactions_id  sale_date sale_time  customer_id  gender   age  \
# 0                 180 2022-11-05  10:47:00          117    Male  41.0
# 1                 522 2022-07-09  11:00:00           52    Male  46.0
# 2                 559 2022-12-12  10:48:00            5  Female  40.0
# 3                1180 2022-01-06  08:53:00           85    Male  41.0
# 4                1522 2022-11-14  08:35:00           48    Male  46.0
# ...               ...        ...       ...          ...     ...   ...
# 1995             1857 2022-11-09  12:15:00          109    Male  60.0
# 1996              211 2022-09-12  14:02:00           54    Male  42.0
# 1997              650 2023-10-08  12:41:00           98    Male  55.0
# 1998             1211 2023-11-22  14:59:00           82    Male  42.0
# 1999             1650 2022-09-23  16:24:00           89    Male  55.0
#
#          category  quantiy  price_per_unit   cogs  total_sale  Revenue  Year  \
# ...

# %%
top_products_quantity = (
    df.groupby('category')['quantiy']
    .sum()
    .sort_values(ascending=False)
    .head(2)
)

# %%
top_products_revenue = (
    df.groupby('category')['Revenue']
    .sum()
    .sort_values(ascending=False)
    .head(2)
)

# %%
top_products_quantity
# Out:
# category
# Clothing       1785.0
# Electronics    1698.0
# Name: quantiy, dtype: float64

# %%
top_products_revenue
# Out:
# category
# Electronics    313810.0
# Clothing       311070.0
# Name: Revenue, dtype: float64

# %%
top_customer_revenue = (df.groupby("customer_id")["Revenue"].sum().sort_values(ascending=False).head(2))

# %%
top_customer_revenue
# Out:
# customer_id
# 3    38440.0
# 1    30750.0
# Name: Revenue, dtype: float64

# %%
customer_orders = (
    df.groupby('customer_id')['transactions_id'].nunique()
)

# %%
customer_orders
# Out:
# customer_id
# 1      76
# 2      69
# 3      76
# 4      73
# 5      63
#        ..
# 151     7
# 152     6
# 153     3
# 154     4
# 155     9
# Name: transactions_id, Length: 155, dtype: int64

# %% [markdown]
# # **TIME SERIES ANALYSIS**

# %%
monthly_revenue = (
    df.groupby(
        df['sale_date'].dt.to_period('M')
    )['Revenue']
    .sum()
)

# %%
monthly_revenue
# Out:
# sale_date
# 2022-01    22635.0
# 2022-02    16110.0
# 2022-03    23455.0
# 2022-04    28535.0
# 2022-05    24480.0
# 2022-06    20700.0
# 2022-07    22195.0
# 2022-08    21075.0
# 2022-09    61620.0
# 2022-10    67735.0
# 2022-11    68915.0
# 2022-12    71880.0
# 2023-01    23790.0
# 2023-02    25170.0
# 2023-03    20530.0
# 2023-04    21925.0
# 2023-05    27010.0
# 2023-06    24555.0
# 2023-07    35925.0
# 2023-08    28270.0
# 2023-09    67560.0
# 2023-10    57880.0
# 2023-11    57135.0
# 2023-12    69145.0
# Freq: M, Name: Revenue, dtype: float64

# %%
monthly_revenue.plot()
plt.title("Monthly Revenue")
plt.xlabel("Month")
plt.ylabel("Revenue")
plt.show()

# %%
ax = top_products_revenue.plot(
    kind="bar",
    color="skyblue"
)

ax.patches[0].set_color("red")

plt.title("Top Categories by Revenue")
plt.xlabel("Category")
plt.ylabel("Revenue")
plt.xticks(rotation=0)
plt.show()

# %%
top_customer_revenue.plot(kind = "bar", color="skyblue")
plt.title("Top customer by revenue")
plt.xlabel("customerID")
plt.ylabel("Revenue")
plt.xticks(rotation=0)
plt.show()

# %%
df["sale_date"] = pd.to_datetime(df["sale_date"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   transactions_id  2000 non-null   int64
#  1   sale_date        2000 non-null   datetime64[ns]
#  2   sale_time        2000 non-null   object
#  3   customer_id      2000 non-null   int64
#  4   gender           2000 non-null   object
#  5   age              1990 non-null   float64
#  6   category         2000 non-null   object
#  7   quantiy          1997 non-null   float64
#  8   price_per_unit   1997 non-null   float64
#  9   cogs             1997 non-null   float64
#  10  total_sale       1997 non-null   float64
#  11  Revenue          1997 non-null   float64
# dtypes: datetime64[ns](1), float64(6), int64(2), object(3)
# memory usage: 187.6+ KB

# %%
revenue_by_day_week = (
    df.groupby("Day_Name")["Revenue"]
    .sum()
    .sort_values(ascending=False)
)

# %%
revenue_by_day_week.plot(kind="bar")
plt.title("revenue_by_day_week")
plt.xlabel("Day_name")
plt.ylabel("Revenue")
plt.xticks(rotation=0)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   transactions_id  2000 non-null   int64
#  1   sale_date        2000 non-null   datetime64[ns]
#  2   sale_time        2000 non-null   object
#  3   customer_id      2000 non-null   int64
#  4   gender           2000 non-null   object
#  5   age              1990 non-null   float64
#  6   category         2000 non-null   object
#  7   quantiy          1997 non-null   float64
#  8   price_per_unit   1997 non-null   float64
#  9   cogs             1997 non-null   float64
#  10  total_sale       1997 non-null   float64
#  11  Revenue          1997 non-null   float64
#  12  Day_Name         2000 non-null   object
# dtypes: datetime64[ns](1), float64(6), int64(2), object(4)
# memory usage: 203.3+ KB

# %% [markdown]
# # **Export Dataset**

# %%
df.to_csv("data/Retail_Sales_clean.csv", index=False)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\aviji\\PycharmProjects\\JupyterProject'
